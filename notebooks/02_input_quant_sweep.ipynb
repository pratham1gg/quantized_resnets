# %% [markdown]
# # 02 — Input bit-depth sweep (PyTorch)
#
# Sweeps input quantization in [0,2,4,8] with fixed network precision.

# %%
from pathlib import Path
import sys, os

# ---- Path setup (adjust if your repo layout differs) ----
PROJECT_ROOT = Path("..").resolve()
SRC = PROJECT_ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

# %%
import pandas as pd

from config import ExperimentConfig, with_overrides
from runner import run_experiment
from utils import load_runs, flatten_runs

pd.set_option("display.max_columns", 200)

# %%
base = ExperimentConfig(
    backend="pytorch",
    device="cuda",
    batch_size=1,       
    seed=42,
    num_eval_batches=500,
)

in_bits_list = [4, 2, 1]

# %%
cfgs32 = [with_overrides(base, input_quant_bits=b, model_precision="fp32") for b in in_bits_list]

records = []
for cfg in cfgs32:
    payload, _ = run_experiment(cfg, save_results_flag=True)
    records.append(payload)

for r in records:
    print(r["run_id"], r["status"], r["results"].get("top1_acc"))
# Out:
# [data] Train: 124,395  Holdout-Val: 5,000  (num_classes=100, val_per_class=50, seed=42)
# Evaluating on 500 batches (first 30 are warmup)...
#   --- Warmup complete (30 batches) — starting metric collection ---
#   Batch [40/500] Top-1: 90.00% | Top-5: 90.00% | Infer: 2.93 ms/batch
#   Batch [50/500] Top-1: 90.00% | Top-5: 90.00% | Infer: 2.98 ms/batch
#   Batch [60/500] Top-1: 93.33% | Top-5: 93.33% | Infer: 2.92 ms/batch
#   Batch [70/500] Top-1: 95.00% | Top-5: 95.00% | Infer: 2.92 ms/batch
#   Batch [80/500] Top-1: 96.00% | Top-5: 96.00% | Infer: 2.91 ms/batch
#   Batch [90/500] Top-1: 96.67% | Top-5: 96.67% | Infer: 2.95 ms/batch
#   Batch [100/500] Top-1: 95.71% | Top-5: 97.14% | Infer: 2.88 ms/batch
#   Batch [110/500] Top-1: 93.75% | Top-5: 97.50% | Infer: 2.90 ms/batch
#   Batch [120/500] Top-1: 92.22% | Top-5: 96.67% | Infer: 2.91 ms/batch
#   Batch [130/500] Top-1: 93.00% | Top-5: 97.00% | Infer: 2.87 ms/batch
#   Batch [140/500] Top-1: 91.82% | Top-5: 96.36% | Infer: 2.90 ms/batch
#   Batch [150/500] Top-1: 91.67% | Top-5: 96.67% | Infer: 2.87 ms/batch
#   Batch [160/500] Top-1: 90.77% | Top-5: 96.92% | Infer: 2.87 ms/batch
#   Batch [170/500] Top-1: 90.00% | Top-5: 97.14% | Infer: 2.87 ms/batch
#   Batch [180/500] Top-1: 88.67% | Top-5: 97.33% | Infer: 2.89 ms/batch
#   Batch [190/500] Top-1: 88.12% | Top-5: 97.50% | Infer: 2.92 ms/batch
#   Batch [200/500] Top-1: 87.65% | Top-5: 97.65% | Infer: 2.93 ms/batch
#   Batch [210/500] Top-1: 86.67% | Top-5: 97.78% | Infer: 2.94 ms/batch
#   Batch [220/500] Top-1: 85.26% | Top-5: 97.89% | Infer: 2.93 ms/batch
#   Batch [230/500] Top-1: 85.00% | Top-5: 98.00% | Infer: 2.95 ms/batch
#   Batch [240/500] Top-1: 84.76% | Top-5: 97.62% | Infer: 2.97 ms/batch
#   Batch [250/500] Top-1: 85.45% | Top-5: 97.73% | Infer: 3.00 ms/batch
#   Batch [260/500] Top-1: 84.78% | Top-5: 97.83% | Infer: 3.02 ms/batch
#   Batch [270/500] Top-1: 85.00% | Top-5: 97.92% | Infer: 3.01 ms/batch
#   Batch [280/500] Top-1: 84.40% | Top-5: 97.60% | Infer: 3.01 ms/batch
#   Batch [290/500] Top-1: 84.23% | Top-5: 97.69% | Infer: 3.00 ms/batch
#   Batch [300/500] Top-1: 83.33% | Top-5: 97.78% | Infer: 3.03 ms/batch
#   Batch [310/500] Top-1: 83.57% | Top-5: 97.86% | Infer: 3.04 ms/batch
#   Batch [320/500] Top-1: 83.45% | Top-5: 97.24% | Infer: 3.04 ms/batch
#   Batch [330/500] Top-1: 82.00% | Top-5: 97.00% | Infer: 3.03 ms/batch
#   Batch [340/500] Top-1: 82.26% | Top-5: 97.10% | Infer: 3.02 ms/batch
#   Batch [350/500] Top-1: 82.19% | Top-5: 97.19% | Infer: 3.01 ms/batch
#   Batch [360/500] Top-1: 82.12% | Top-5: 97.27% | Infer: 3.02 ms/batch
#   Batch [370/500] Top-1: 82.06% | Top-5: 97.35% | Infer: 3.02 ms/batch
#   Batch [380/500] Top-1: 82.00% | Top-5: 97.43% | Infer: 3.01 ms/batch
#   Batch [390/500] Top-1: 81.94% | Top-5: 97.22% | Infer: 2.99 ms/batch
#   Batch [400/500] Top-1: 81.89% | Top-5: 97.03% | Infer: 2.99 ms/batch
#   Batch [410/500] Top-1: 81.84% | Top-5: 97.11% | Infer: 2.99 ms/batch
#   Batch [420/500] Top-1: 81.54% | Top-5: 97.18% | Infer: 3.01 ms/batch
#   Batch [430/500] Top-1: 81.50% | Top-5: 97.00% | Infer: 3.00 ms/batch
#   Batch [440/500] Top-1: 81.22% | Top-5: 96.83% | Infer: 3.00 ms/batch
#   Batch [450/500] Top-1: 81.43% | Top-5: 96.90% | Infer: 3.00 ms/batch
#   Batch [460/500] Top-1: 81.86% | Top-5: 96.98% | Infer: 2.98 ms/batch
#   Batch [470/500] Top-1: 82.27% | Top-5: 97.05% | Infer: 2.97 ms/batch
#   Batch [480/500] Top-1: 82.67% | Top-5: 97.11% | Infer: 2.98 ms/batch
#   Batch [490/500] Top-1: 83.04% | Top-5: 97.17% | Infer: 2.97 ms/batch
#   Batch [500/500] Top-1: 83.40% | Top-5: 97.23% | Infer: 2.97 ms/batch
# [runner] Results saved: ../runs/resnet18_pytorch_fp32_in4b_cuda_bs1/result.json
# [data] Train: 124,395  Holdout-Val: 5,000  (num_classes=100, val_per_class=50, seed=42)
# Evaluating on 500 batches (first 30 are warmup)...
#   --- Warmup complete (30 batches) — starting metric collection ---
#   Batch [40/500] Top-1: 60.00% | Top-5: 70.00% | Infer: 3.82 ms/batch
#   Batch [50/500] Top-1: 60.00% | Top-5: 70.00% | Infer: 3.27 ms/batch
#   Batch [60/500] Top-1: 70.00% | Top-5: 80.00% | Infer: 2.93 ms/batch
#   Batch [70/500] Top-1: 77.50% | Top-5: 85.00% | Infer: 2.86 ms/batch
#   Batch [80/500] Top-1: 82.00% | Top-5: 88.00% | Infer: 2.80 ms/batch
#   Batch [90/500] Top-1: 80.00% | Top-5: 88.33% | Infer: 2.85 ms/batch
#   Batch [100/500] Top-1: 80.00% | Top-5: 90.00% | Infer: 2.86 ms/batch
#   Batch [110/500] Top-1: 76.25% | Top-5: 86.25% | Infer: 2.83 ms/batch
#   Batch [120/500] Top-1: 72.22% | Top-5: 86.67% | Infer: 2.86 ms/batch
#   Batch [130/500] Top-1: 69.00% | Top-5: 86.00% | Infer: 2.88 ms/batch
#   Batch [140/500] Top-1: 65.45% | Top-5: 83.64% | Infer: 2.83 ms/batch
#   Batch [150/500] Top-1: 64.17% | Top-5: 80.83% | Infer: 2.84 ms/batch
#   Batch [160/500] Top-1: 63.08% | Top-5: 81.54% | Infer: 2.85 ms/batch
#   Batch [170/500] Top-1: 60.00% | Top-5: 80.71% | Infer: 2.88 ms/batch
#   Batch [180/500] Top-1: 57.33% | Top-5: 78.00% | Infer: 2.90 ms/batch
#   Batch [190/500] Top-1: 54.38% | Top-5: 76.88% | Infer: 2.91 ms/batch
#   Batch [200/500] Top-1: 52.35% | Top-5: 75.88% | Infer: 2.90 ms/batch
#   Batch [210/500] Top-1: 50.56% | Top-5: 77.22% | Infer: 2.90 ms/batch
#   Batch [220/500] Top-1: 50.53% | Top-5: 77.37% | Infer: 2.88 ms/batch
#   Batch [230/500] Top-1: 50.00% | Top-5: 76.50% | Infer: 2.88 ms/batch
#   Batch [240/500] Top-1: 50.00% | Top-5: 77.14% | Infer: 2.87 ms/batch
#   Batch [250/500] Top-1: 49.09% | Top-5: 77.27% | Infer: 2.85 ms/batch
#   Batch [260/500] Top-1: 49.13% | Top-5: 77.39% | Infer: 2.85 ms/batch
#   Batch [270/500] Top-1: 48.75% | Top-5: 76.67% | Infer: 2.86 ms/batch
#   Batch [280/500] Top-1: 48.40% | Top-5: 76.00% | Infer: 2.85 ms/batch
#   Batch [290/500] Top-1: 48.46% | Top-5: 75.77% | Infer: 2.88 ms/batch
#   Batch [300/500] Top-1: 48.52% | Top-5: 76.30% | Infer: 2.87 ms/batch
#   Batch [310/500] Top-1: 48.57% | Top-5: 75.71% | Infer: 2.86 ms/batch
#   Batch [320/500] Top-1: 48.28% | Top-5: 75.17% | Infer: 2.86 ms/batch
#   Batch [330/500] Top-1: 48.00% | Top-5: 75.00% | Infer: 2.86 ms/batch
#   Batch [340/500] Top-1: 48.71% | Top-5: 75.48% | Infer: 2.87 ms/batch
#   Batch [350/500] Top-1: 47.81% | Top-5: 74.69% | Infer: 2.84 ms/batch
#   Batch [360/500] Top-1: 49.09% | Top-5: 75.45% | Infer: 2.85 ms/batch
#   Batch [370/500] Top-1: 50.00% | Top-5: 75.88% | Infer: 2.86 ms/batch
#   Batch [380/500] Top-1: 50.57% | Top-5: 76.57% | Infer: 2.85 ms/batch
#   Batch [390/500] Top-1: 51.39% | Top-5: 77.22% | Infer: 2.84 ms/batch
#   Batch [400/500] Top-1: 51.62% | Top-5: 77.03% | Infer: 2.82 ms/batch
#   Batch [410/500] Top-1: 50.79% | Top-5: 77.11% | Infer: 2.83 ms/batch
#   Batch [420/500] Top-1: 50.77% | Top-5: 77.44% | Infer: 2.83 ms/batch
#   Batch [430/500] Top-1: 50.50% | Top-5: 77.50% | Infer: 2.85 ms/batch
#   Batch [440/500] Top-1: 50.00% | Top-5: 77.32% | Infer: 2.85 ms/batch
#   Batch [450/500] Top-1: 50.24% | Top-5: 77.38% | Infer: 2.85 ms/batch
#   Batch [460/500] Top-1: 50.23% | Top-5: 77.44% | Infer: 2.85 ms/batch
#   Batch [470/500] Top-1: 50.68% | Top-5: 77.95% | Infer: 2.85 ms/batch
#   Batch [480/500] Top-1: 51.33% | Top-5: 78.22% | Infer: 2.84 ms/batch
#   Batch [490/500] Top-1: 51.74% | Top-5: 78.48% | Infer: 2.84 ms/batch
#   Batch [500/500] Top-1: 52.13% | Top-5: 78.51% | Infer: 2.84 ms/batch
# [runner] Results saved: ../runs/resnet18_pytorch_fp32_in2b_cuda_bs1/result.json
# [data] Train: 124,395  Holdout-Val: 5,000  (num_classes=100, val_per_class=50, seed=42)
# Evaluating on 500 batches (first 30 are warmup)...
#   --- Warmup complete (30 batches) — starting metric collection ---
#   Batch [40/500] Top-1: 30.00% | Top-5: 40.00% | Infer: 2.75 ms/batch
#   Batch [50/500] Top-1: 35.00% | Top-5: 45.00% | Infer: 2.76 ms/batch
#   Batch [60/500] Top-1: 46.67% | Top-5: 60.00% | Infer: 2.85 ms/batch
#   Batch [70/500] Top-1: 50.00% | Top-5: 70.00% | Infer: 2.78 ms/batch
#   Batch [80/500] Top-1: 54.00% | Top-5: 76.00% | Infer: 2.85 ms/batch
#   Batch [90/500] Top-1: 55.00% | Top-5: 78.33% | Infer: 2.81 ms/batch
#   Batch [100/500] Top-1: 55.71% | Top-5: 80.00% | Infer: 2.84 ms/batch
#   Batch [110/500] Top-1: 52.50% | Top-5: 76.25% | Infer: 2.85 ms/batch
#   Batch [120/500] Top-1: 48.89% | Top-5: 71.11% | Infer: 2.93 ms/batch
#   Batch [130/500] Top-1: 44.00% | Top-5: 68.00% | Infer: 2.92 ms/batch
#   Batch [140/500] Top-1: 40.00% | Top-5: 64.55% | Infer: 2.89 ms/batch
#   Batch [150/500] Top-1: 38.33% | Top-5: 63.33% | Infer: 2.89 ms/batch
#   Batch [160/500] Top-1: 35.38% | Top-5: 60.77% | Infer: 2.91 ms/batch
#   Batch [170/500] Top-1: 32.86% | Top-5: 58.57% | Infer: 2.94 ms/batch
#   Batch [180/500] Top-1: 30.67% | Top-5: 55.33% | Infer: 2.93 ms/batch
#   Batch [190/500] Top-1: 30.00% | Top-5: 54.38% | Infer: 2.96 ms/batch
#   Batch [200/500] Top-1: 28.82% | Top-5: 52.94% | Infer: 2.99 ms/batch
#   Batch [210/500] Top-1: 28.33% | Top-5: 52.22% | Infer: 3.01 ms/batch
#   Batch [220/500] Top-1: 27.37% | Top-5: 52.11% | Infer: 2.99 ms/batch
#   Batch [230/500] Top-1: 27.00% | Top-5: 52.00% | Infer: 2.98 ms/batch
#   Batch [240/500] Top-1: 26.67% | Top-5: 51.43% | Infer: 2.95 ms/batch
#   Batch [250/500] Top-1: 27.27% | Top-5: 52.73% | Infer: 2.97 ms/batch
#   Batch [260/500] Top-1: 27.83% | Top-5: 53.48% | Infer: 2.98 ms/batch
#   Batch [270/500] Top-1: 27.92% | Top-5: 53.33% | Infer: 3.01 ms/batch
#   Batch [280/500] Top-1: 27.60% | Top-5: 52.00% | Infer: 3.05 ms/batch
#   Batch [290/500] Top-1: 27.31% | Top-5: 52.31% | Infer: 3.06 ms/batch
#   Batch [300/500] Top-1: 27.04% | Top-5: 52.59% | Infer: 3.06 ms/batch
#   Batch [310/500] Top-1: 27.86% | Top-5: 52.86% | Infer: 3.06 ms/batch
#   Batch [320/500] Top-1: 26.90% | Top-5: 51.72% | Infer: 3.10 ms/batch
#   Batch [330/500] Top-1: 26.00% | Top-5: 51.67% | Infer: 3.09 ms/batch
#   Batch [340/500] Top-1: 26.45% | Top-5: 51.94% | Infer: 3.10 ms/batch
#   Batch [350/500] Top-1: 26.56% | Top-5: 51.25% | Infer: 3.10 ms/batch
#   Batch [360/500] Top-1: 27.27% | Top-5: 52.42% | Infer: 3.10 ms/batch
#   Batch [370/500] Top-1: 28.53% | Top-5: 53.82% | Infer: 3.09 ms/batch
#   Batch [380/500] Top-1: 29.43% | Top-5: 54.86% | Infer: 3.09 ms/batch
#   Batch [390/500] Top-1: 30.28% | Top-5: 55.56% | Infer: 3.08 ms/batch
#   Batch [400/500] Top-1: 31.35% | Top-5: 56.49% | Infer: 3.09 ms/batch
#   Batch [410/500] Top-1: 31.05% | Top-5: 56.05% | Infer: 3.08 ms/batch
#   Batch [420/500] Top-1: 30.77% | Top-5: 56.15% | Infer: 3.07 ms/batch
#   Batch [430/500] Top-1: 30.25% | Top-5: 56.00% | Infer: 3.08 ms/batch
#   Batch [440/500] Top-1: 29.51% | Top-5: 55.61% | Infer: 3.08 ms/batch
#   Batch [450/500] Top-1: 28.81% | Top-5: 54.76% | Infer: 3.08 ms/batch
#   Batch [460/500] Top-1: 29.53% | Top-5: 55.12% | Infer: 3.08 ms/batch
#   Batch [470/500] Top-1: 30.00% | Top-5: 55.45% | Infer: 3.09 ms/batch
#   Batch [480/500] Top-1: 30.22% | Top-5: 56.00% | Infer: 3.09 ms/batch
#   Batch [490/500] Top-1: 30.00% | Top-5: 55.87% | Infer: 3.07 ms/batch
#   Batch [500/500] Top-1: 30.21% | Top-5: 56.17% | Infer: 3.06 ms/batch
# [runner] Results saved: ../runs/resnet18_pytorch_fp32_in1b_cuda_bs1/result.json
# resnet18_pytorch_fp32_in4b_cuda_bs1 ok 83.40425531914893
# resnet18_pytorch_fp32_in2b_cuda_bs1 ok 52.12765957446808
# resnet18_pytorch_fp32_in1b_cuda_bs1 ok 30.21276595744681

# %%
runs = load_runs("../runs", status="ok")
rows = flatten_runs(runs)
df = pd.DataFrame(rows)

# Filter only what this notebook is responsible for
df_sweep = df[
    (df["cfg.backend"] == "pytorch")
    & (df["cfg.device"] == "cuda")
    & (df["cfg.model_precision"].isin(["fp32"])) 
    & (df["cfg.input_quant_bits"].isin([8, 4, 2, 1]))
].copy()

df_sweep[[
    "run_id",
    "res.top1_acc",
    "res.top5_acc",
    "res.infer_ms_avg",
    "res.throughput_infer_sps",
    "res.total_samples",
]].sort_values(["run_id"])
# Out:
#                                 run_id  res.top1_acc  res.top5_acc  \
# 1  resnet18_pytorch_fp32_in1b_cuda_bs1     30.212766     56.170213
# 2  resnet18_pytorch_fp32_in2b_cuda_bs1     52.127660     78.510638
# 3  resnet18_pytorch_fp32_in4b_cuda_bs1     83.404255     97.234043
# 4  resnet18_pytorch_fp32_in8b_cuda_bs1     87.021277     97.872340
#
#    res.infer_ms_avg  res.throughput_infer_sps  res.total_samples
# 1          3.063963                326.374665                470
# 2          2.841536                351.922284                470
# 3          2.973662                336.285747                470
# 4          3.199306                312.567780                470

# %%
cfgs16 = [with_overrides(base, input_quant_bits=b, model_precision="fp16") for b in in_bits_list]

records = []
for cfg in cfgs16:
    payload, _ = run_experiment(cfg, save_results_flag=True)
    records.append(payload)

for r in records:
    print(r["run_id"], r["status"], r["results"].get("top1_acc"))
# Out:
# [data] Train: 124,395  Holdout-Val: 5,000  (num_classes=100, val_per_class=50, seed=42)
# Evaluating on 500 batches (first 30 are warmup)...
#   --- Warmup complete (30 batches) — starting metric collection ---
#   Batch [40/500] Top-1: 90.00% | Top-5: 90.00% | Infer: 3.99 ms/batch
#   Batch [50/500] Top-1: 90.00% | Top-5: 90.00% | Infer: 3.49 ms/batch
#   Batch [60/500] Top-1: 93.33% | Top-5: 93.33% | Infer: 3.39 ms/batch
#   Batch [70/500] Top-1: 95.00% | Top-5: 95.00% | Infer: 3.32 ms/batch
#   Batch [80/500] Top-1: 96.00% | Top-5: 96.00% | Infer: 3.13 ms/batch
#   Batch [90/500] Top-1: 96.67% | Top-5: 96.67% | Infer: 2.98 ms/batch
#   Batch [100/500] Top-1: 95.71% | Top-5: 97.14% | Infer: 2.84 ms/batch
#   Batch [110/500] Top-1: 93.75% | Top-5: 97.50% | Infer: 2.85 ms/batch
#   Batch [120/500] Top-1: 92.22% | Top-5: 96.67% | Infer: 2.84 ms/batch
#   Batch [130/500] Top-1: 93.00% | Top-5: 97.00% | Infer: 2.75 ms/batch
#   Batch [140/500] Top-1: 91.82% | Top-5: 96.36% | Infer: 2.88 ms/batch
#   Batch [150/500] Top-1: 91.67% | Top-5: 96.67% | Infer: 2.93 ms/batch
#   Batch [160/500] Top-1: 90.77% | Top-5: 96.92% | Infer: 2.91 ms/batch
#   Batch [170/500] Top-1: 90.00% | Top-5: 97.14% | Infer: 2.94 ms/batch
#   Batch [180/500] Top-1: 88.67% | Top-5: 97.33% | Infer: 2.96 ms/batch
#   Batch [190/500] Top-1: 88.12% | Top-5: 97.50% | Infer: 3.01 ms/batch
#   Batch [200/500] Top-1: 87.65% | Top-5: 97.65% | Infer: 3.01 ms/batch
#   Batch [210/500] Top-1: 86.67% | Top-5: 97.78% | Infer: 3.02 ms/batch
#   Batch [220/500] Top-1: 85.26% | Top-5: 97.89% | Infer: 3.01 ms/batch
#   Batch [230/500] Top-1: 85.00% | Top-5: 98.00% | Infer: 3.02 ms/batch
#   Batch [240/500] Top-1: 84.76% | Top-5: 97.62% | Infer: 3.00 ms/batch
#   Batch [250/500] Top-1: 85.45% | Top-5: 97.73% | Infer: 3.03 ms/batch
#   Batch [260/500] Top-1: 84.78% | Top-5: 97.83% | Infer: 3.03 ms/batch
#   Batch [270/500] Top-1: 85.00% | Top-5: 97.92% | Infer: 3.02 ms/batch
#   Batch [280/500] Top-1: 84.40% | Top-5: 97.60% | Infer: 3.01 ms/batch
#   Batch [290/500] Top-1: 84.23% | Top-5: 97.69% | Infer: 2.97 ms/batch
#   Batch [300/500] Top-1: 83.33% | Top-5: 97.78% | Infer: 2.97 ms/batch
#   Batch [310/500] Top-1: 83.57% | Top-5: 97.86% | Infer: 2.96 ms/batch
#   Batch [320/500] Top-1: 83.45% | Top-5: 97.24% | Infer: 2.98 ms/batch
#   Batch [330/500] Top-1: 82.00% | Top-5: 97.00% | Infer: 2.99 ms/batch
#   Batch [340/500] Top-1: 82.26% | Top-5: 97.10% | Infer: 3.02 ms/batch
#   Batch [350/500] Top-1: 82.19% | Top-5: 97.19% | Infer: 3.02 ms/batch
#   Batch [360/500] Top-1: 82.12% | Top-5: 97.27% | Infer: 3.01 ms/batch
#   Batch [370/500] Top-1: 82.06% | Top-5: 97.35% | Infer: 3.01 ms/batch
#   Batch [380/500] Top-1: 82.00% | Top-5: 97.43% | Infer: 3.00 ms/batch
#   Batch [390/500] Top-1: 81.94% | Top-5: 97.22% | Infer: 2.99 ms/batch
#   Batch [400/500] Top-1: 81.89% | Top-5: 97.03% | Infer: 2.99 ms/batch
#   Batch [410/500] Top-1: 81.84% | Top-5: 97.11% | Infer: 2.99 ms/batch
#   Batch [420/500] Top-1: 81.54% | Top-5: 97.18% | Infer: 2.98 ms/batch
#   Batch [430/500] Top-1: 81.50% | Top-5: 97.00% | Infer: 2.97 ms/batch
#   Batch [440/500] Top-1: 81.22% | Top-5: 96.83% | Infer: 2.98 ms/batch
#   Batch [450/500] Top-1: 81.43% | Top-5: 96.90% | Infer: 2.97 ms/batch
#   Batch [460/500] Top-1: 81.86% | Top-5: 96.98% | Infer: 2.96 ms/batch
#   Batch [470/500] Top-1: 82.27% | Top-5: 97.05% | Infer: 2.99 ms/batch
#   Batch [480/500] Top-1: 82.67% | Top-5: 97.11% | Infer: 2.98 ms/batch
#   Batch [490/500] Top-1: 83.04% | Top-5: 97.17% | Infer: 3.00 ms/batch
#   Batch [500/500] Top-1: 83.40% | Top-5: 97.23% | Infer: 3.00 ms/batch
# [runner] Results saved: ../runs/resnet18_pytorch_fp16_in4b_cuda_bs1/result.json
# [data] Train: 124,395  Holdout-Val: 5,000  (num_classes=100, val_per_class=50, seed=42)
# Evaluating on 500 batches (first 30 are warmup)...
#   --- Warmup complete (30 batches) — starting metric collection ---
#   Batch [40/500] Top-1: 60.00% | Top-5: 70.00% | Infer: 3.36 ms/batch
#   Batch [50/500] Top-1: 60.00% | Top-5: 70.00% | Infer: 3.35 ms/batch
#   Batch [60/500] Top-1: 70.00% | Top-5: 80.00% | Infer: 3.08 ms/batch
#   Batch [70/500] Top-1: 77.50% | Top-5: 85.00% | Infer: 3.13 ms/batch
#   Batch [80/500] Top-1: 82.00% | Top-5: 88.00% | Infer: 3.02 ms/batch
#   Batch [90/500] Top-1: 80.00% | Top-5: 88.33% | Infer: 3.01 ms/batch
#   Batch [100/500] Top-1: 80.00% | Top-5: 90.00% | Infer: 3.14 ms/batch
#   Batch [110/500] Top-1: 76.25% | Top-5: 86.25% | Infer: 3.18 ms/batch
#   Batch [120/500] Top-1: 72.22% | Top-5: 86.67% | Infer: 3.18 ms/batch
#   Batch [130/500] Top-1: 69.00% | Top-5: 86.00% | Infer: 3.21 ms/batch
#   Batch [140/500] Top-1: 65.45% | Top-5: 83.64% | Infer: 3.23 ms/batch
#   Batch [150/500] Top-1: 64.17% | Top-5: 80.83% | Infer: 3.20 ms/batch
#   Batch [160/500] Top-1: 63.08% | Top-5: 81.54% | Infer: 3.15 ms/batch
#   Batch [170/500] Top-1: 60.00% | Top-5: 80.71% | Infer: 3.14 ms/batch
#   Batch [180/500] Top-1: 57.33% | Top-5: 78.00% | Infer: 3.12 ms/batch
#   Batch [190/500] Top-1: 54.38% | Top-5: 76.88% | Infer: 3.10 ms/batch
#   Batch [200/500] Top-1: 52.35% | Top-5: 75.88% | Infer: 3.12 ms/batch
#   Batch [210/500] Top-1: 50.56% | Top-5: 77.22% | Infer: 3.10 ms/batch
#   Batch [220/500] Top-1: 50.53% | Top-5: 77.37% | Infer: 3.07 ms/batch
#   Batch [230/500] Top-1: 50.00% | Top-5: 76.50% | Infer: 3.05 ms/batch
#   Batch [240/500] Top-1: 50.00% | Top-5: 77.14% | Infer: 3.05 ms/batch
#   Batch [250/500] Top-1: 49.09% | Top-5: 77.27% | Infer: 3.04 ms/batch
#   Batch [260/500] Top-1: 49.13% | Top-5: 77.39% | Infer: 3.03 ms/batch
#   Batch [270/500] Top-1: 48.75% | Top-5: 76.67% | Infer: 3.07 ms/batch
#   Batch [280/500] Top-1: 48.40% | Top-5: 76.00% | Infer: 3.04 ms/batch
#   Batch [290/500] Top-1: 48.46% | Top-5: 75.77% | Infer: 3.04 ms/batch
#   Batch [300/500] Top-1: 48.52% | Top-5: 76.30% | Infer: 3.04 ms/batch
#   Batch [310/500] Top-1: 48.57% | Top-5: 75.71% | Infer: 3.01 ms/batch
#   Batch [320/500] Top-1: 48.28% | Top-5: 75.17% | Infer: 3.00 ms/batch
#   Batch [330/500] Top-1: 48.00% | Top-5: 75.00% | Infer: 3.00 ms/batch
#   Batch [340/500] Top-1: 48.71% | Top-5: 75.48% | Infer: 3.03 ms/batch
#   Batch [350/500] Top-1: 47.81% | Top-5: 74.69% | Infer: 3.04 ms/batch
#   Batch [360/500] Top-1: 49.09% | Top-5: 75.45% | Infer: 3.02 ms/batch
#   Batch [370/500] Top-1: 50.00% | Top-5: 75.88% | Infer: 3.02 ms/batch
#   Batch [380/500] Top-1: 50.57% | Top-5: 76.57% | Infer: 3.00 ms/batch
#   Batch [390/500] Top-1: 51.39% | Top-5: 77.22% | Infer: 2.99 ms/batch
#   Batch [400/500] Top-1: 51.62% | Top-5: 77.03% | Infer: 3.00 ms/batch
#   Batch [410/500] Top-1: 50.79% | Top-5: 77.11% | Infer: 2.99 ms/batch
#   Batch [420/500] Top-1: 50.77% | Top-5: 77.44% | Infer: 2.98 ms/batch
#   Batch [430/500] Top-1: 50.50% | Top-5: 77.50% | Infer: 3.00 ms/batch
#   Batch [440/500] Top-1: 50.00% | Top-5: 77.32% | Infer: 2.99 ms/batch
#   Batch [450/500] Top-1: 50.24% | Top-5: 77.38% | Infer: 2.99 ms/batch
#   Batch [460/500] Top-1: 50.23% | Top-5: 77.44% | Infer: 2.97 ms/batch
#   Batch [470/500] Top-1: 50.68% | Top-5: 77.95% | Infer: 2.97 ms/batch
#   Batch [480/500] Top-1: 51.33% | Top-5: 78.22% | Infer: 2.96 ms/batch
#   Batch [490/500] Top-1: 51.74% | Top-5: 78.48% | Infer: 2.97 ms/batch
#   Batch [500/500] Top-1: 52.13% | Top-5: 78.51% | Infer: 2.96 ms/batch
# [runner] Results saved: ../runs/resnet18_pytorch_fp16_in2b_cuda_bs1/result.json
# [data] Train: 124,395  Holdout-Val: 5,000  (num_classes=100, val_per_class=50, seed=42)
# Evaluating on 500 batches (first 30 are warmup)...
#   --- Warmup complete (30 batches) — starting metric collection ---
#   Batch [40/500] Top-1: 30.00% | Top-5: 40.00% | Infer: 3.23 ms/batch
#   Batch [50/500] Top-1: 35.00% | Top-5: 45.00% | Infer: 2.85 ms/batch
#   Batch [60/500] Top-1: 46.67% | Top-5: 60.00% | Infer: 2.80 ms/batch
#   Batch [70/500] Top-1: 50.00% | Top-5: 70.00% | Infer: 2.78 ms/batch
#   Batch [80/500] Top-1: 54.00% | Top-5: 76.00% | Infer: 2.80 ms/batch
#   Batch [90/500] Top-1: 55.00% | Top-5: 78.33% | Infer: 2.84 ms/batch
#   Batch [100/500] Top-1: 55.71% | Top-5: 80.00% | Infer: 2.86 ms/batch
#   Batch [110/500] Top-1: 52.50% | Top-5: 76.25% | Infer: 2.85 ms/batch
#   Batch [120/500] Top-1: 48.89% | Top-5: 71.11% | Infer: 2.84 ms/batch
#   Batch [130/500] Top-1: 44.00% | Top-5: 68.00% | Infer: 2.84 ms/batch
#   Batch [140/500] Top-1: 40.00% | Top-5: 64.55% | Infer: 2.90 ms/batch
#   Batch [150/500] Top-1: 38.33% | Top-5: 63.33% | Infer: 2.94 ms/batch
#   Batch [160/500] Top-1: 35.38% | Top-5: 60.77% | Infer: 2.95 ms/batch
#   Batch [170/500] Top-1: 32.86% | Top-5: 58.57% | Infer: 2.95 ms/batch
#   Batch [180/500] Top-1: 30.67% | Top-5: 55.33% | Infer: 2.99 ms/batch
#   Batch [190/500] Top-1: 30.00% | Top-5: 54.38% | Infer: 2.96 ms/batch
#   Batch [200/500] Top-1: 28.82% | Top-5: 52.94% | Infer: 2.97 ms/batch
#   Batch [210/500] Top-1: 28.33% | Top-5: 52.22% | Infer: 2.97 ms/batch
#   Batch [220/500] Top-1: 27.37% | Top-5: 52.11% | Infer: 3.00 ms/batch
#   Batch [230/500] Top-1: 27.00% | Top-5: 52.00% | Infer: 2.96 ms/batch
#   Batch [240/500] Top-1: 26.67% | Top-5: 51.43% | Infer: 2.99 ms/batch
#   Batch [250/500] Top-1: 27.27% | Top-5: 52.73% | Infer: 3.01 ms/batch
#   Batch [260/500] Top-1: 27.83% | Top-5: 53.48% | Infer: 3.03 ms/batch
#   Batch [270/500] Top-1: 27.92% | Top-5: 53.33% | Infer: 3.08 ms/batch
#   Batch [280/500] Top-1: 27.60% | Top-5: 52.00% | Infer: 3.10 ms/batch
#   Batch [290/500] Top-1: 27.31% | Top-5: 52.31% | Infer: 3.11 ms/batch
#   Batch [300/500] Top-1: 27.04% | Top-5: 52.59% | Infer: 3.11 ms/batch
#   Batch [310/500] Top-1: 27.86% | Top-5: 52.86% | Infer: 3.10 ms/batch
#   Batch [320/500] Top-1: 26.90% | Top-5: 51.72% | Infer: 3.12 ms/batch
#   Batch [330/500] Top-1: 26.00% | Top-5: 51.67% | Infer: 3.10 ms/batch
#   Batch [340/500] Top-1: 26.45% | Top-5: 51.94% | Infer: 3.11 ms/batch
#   Batch [350/500] Top-1: 26.56% | Top-5: 51.25% | Infer: 3.13 ms/batch
#   Batch [360/500] Top-1: 27.27% | Top-5: 52.42% | Infer: 3.14 ms/batch
#   Batch [370/500] Top-1: 28.53% | Top-5: 53.82% | Infer: 3.13 ms/batch
#   Batch [380/500] Top-1: 29.43% | Top-5: 54.86% | Infer: 3.15 ms/batch
#   Batch [390/500] Top-1: 30.28% | Top-5: 55.56% | Infer: 3.14 ms/batch
#   Batch [400/500] Top-1: 31.35% | Top-5: 56.49% | Infer: 3.13 ms/batch
#   Batch [410/500] Top-1: 31.05% | Top-5: 56.05% | Infer: 3.13 ms/batch
#   Batch [420/500] Top-1: 30.77% | Top-5: 56.15% | Infer: 3.13 ms/batch
#   Batch [430/500] Top-1: 30.25% | Top-5: 56.00% | Infer: 3.15 ms/batch
#   Batch [440/500] Top-1: 29.51% | Top-5: 55.61% | Infer: 3.15 ms/batch
#   Batch [450/500] Top-1: 28.81% | Top-5: 54.76% | Infer: 3.13 ms/batch
#   Batch [460/500] Top-1: 29.53% | Top-5: 55.12% | Infer: 3.13 ms/batch
#   Batch [470/500] Top-1: 30.00% | Top-5: 55.45% | Infer: 3.12 ms/batch
#   Batch [480/500] Top-1: 30.22% | Top-5: 56.00% | Infer: 3.12 ms/batch
#   Batch [490/500] Top-1: 30.00% | Top-5: 55.87% | Infer: 3.12 ms/batch
#   Batch [500/500] Top-1: 30.21% | Top-5: 56.17% | Infer: 3.13 ms/batch
# [runner] Results saved: ../runs/resnet18_pytorch_fp16_in1b_cuda_bs1/result.json
# resnet18_pytorch_fp16_in4b_cuda_bs1 ok 83.40425531914893
# resnet18_pytorch_fp16_in2b_cuda_bs1 ok 52.12765957446808
# resnet18_pytorch_fp16_in1b_cuda_bs1 ok 30.21276595744681

# %%
runs = load_runs("../runs", status="ok")
rows = flatten_runs(runs)
df = pd.DataFrame(rows)

# Filter only what this notebook is responsible for
df_sweep = df[
    (df["cfg.backend"] == "pytorch")
    & (df["cfg.device"] == "cuda")
    & (df["cfg.model_precision"].isin(["fp16"])) 
    & (df["cfg.input_quant_bits"].isin([8, 4, 2, 1]))
].copy()

df_sweep[[
    "run_id",
    "res.top1_acc",
    "res.top5_acc",
    "res.infer_ms_avg",
    "res.throughput_infer_sps",
    "res.total_samples",
]].sort_values(["run_id"])
# Out:
#                                 run_id  res.top1_acc  res.top5_acc  \
# 0  resnet18_pytorch_fp16_in1b_cuda_bs1     30.212766     56.170213
# 1  resnet18_pytorch_fp16_in2b_cuda_bs1     52.127660     78.510638
# 2  resnet18_pytorch_fp16_in4b_cuda_bs1     83.404255     97.234043
# 3  resnet18_pytorch_fp16_in8b_cuda_bs1     87.021277     97.872340
#
#    res.infer_ms_avg  res.throughput_infer_sps  res.total_samples
# 0          3.125864                319.911543                470
# 1          2.961821                337.630101                470
# 2          3.003669                332.926117                470
# 3          2.997852                333.572219                470

# %%
import matplotlib.pyplot as plt

runs = load_runs("../runs", status="ok")
rows = flatten_runs(runs)
df = pd.DataFrame(rows)

# Filter base conditions
base_filter = (df["cfg.backend"] == "pytorch") & (df["cfg.input_quant_bits"].isin([8, 4, 2, 1]))

plt.figure(figsize=(10, 6))

bit_values = sorted(df[base_filter]["cfg.input_quant_bits"].unique())

for precision, marker in [("fp32", "o"), ("fp16", "s")]:
    df_filtered = df[base_filter & (df["cfg.model_precision"] == precision)].sort_values("cfg.input_quant_bits")
    avgs = df_filtered["res.infer_ms_avg"].values
    mins = df_filtered["res.infer_ms_min"].values
    maxs = df_filtered["res.infer_ms_max"].values
    x_vals = [list(bit_values).index(b) for b in df_filtered["cfg.input_quant_bits"].values]

    plt.errorbar(x_vals, avgs, yerr=[avgs - mins, maxs - avgs], marker=marker,
                 capsize=4, linewidth=1.5, markersize=7, label=precision.upper())

plt.xlabel("Input Quantization Bits", fontsize=12)
plt.ylabel("Inference Time (ms)", fontsize=12)
plt.title("Inference Time vs Input Bit-Depth", fontsize=14)
plt.xticks(bit_values)
plt.legend(fontsize=11)
plt.grid(True, alpha=0.3, axis='y')
plt.tight_layout()
plt.show()

# %%
#accuracy is same for both fp16 and fp32
