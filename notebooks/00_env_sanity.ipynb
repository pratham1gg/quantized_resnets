# %% [markdown]
# # 00 — Environment Sanity
#
# - Notebooks only define sweep configs + call `run_experiment(cfg)`.
# - All results are written under `./runs/<run_id>/result.json` by `runner.py`.

# %%
from pathlib import Path
import sys, os

# ---- Path setup (adjust if your repo layout differs) ----
PROJECT_ROOT = Path("..").resolve()
SRC = PROJECT_ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

# %%
import torch
import pandas as pd

from config import ExperimentConfig, with_overrides
from runner import run_experiment

print("torch:", torch.__version__)
print("cuda available:", torch.cuda.is_available())
# Out:
# torch: 2.10.0+cu128
# cuda available: True

# %%
base = ExperimentConfig(
    device="cuda" if torch.cuda.is_available() else "cpu",
    batch_size=1,
    num_workers=8,
    seed=42,
    num_eval_batches=500,  
)

base.validate()
print("run root:", base.output_root)
# Out:
# run root: ../runs

# %%
#quick sanity
cfg = with_overrides(base, backend="pytorch", model_precision="fp32", input_quant_bits=8, num_eval_batches=10)
payload, _ = run_experiment(cfg, save_results_flag=True)
payload["results"]
# Out:
# Evaluating on 10 batches...
#   Batch [10/10] Top-1: 78.52% | Top-5: 93.16% | Infer: 112.14 ms/batch
# [runner] Results saved: ../runs/resnet18_pytorch_fp32_in8b_cuda_bs256/result.json
# {'top1_acc': 78.515625,
#  'top5_acc': 93.1640625,
#  'loss_avg': 0.8500446796417236,
#  'batch_ms_avg': 118.70591237675399,
#  'infer_ms_avg': 112.13933480903506,
#  'infer_ms_std': 4.642323636586518,
#  'throughput_infer_sps': 2282.8742513583566,
#  'throughput_sps': 2156.590138387514,
#  'total_samples': 2560,
#  'total_batches': 10}
